# %%
# !pip install pyaxis
# !pip install pandasql
# Out:
# Requirement already satisfied: pyaxis in /usr/local/lib/python3.11/dist-packages (0.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyaxis) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pyaxis) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pyaxis) (2.2.2)
# Requirement already satisfied: pyjstat in /usr/local/lib/python3.11/dist-packages (from pyaxis) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pyaxis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pyaxis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pyaxis) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pyaxis) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pyaxis) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pyaxis) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pyaxis) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pyaxis) (1.17.0)
# Requirement already satisfied: pandasql in /usr/local/lib/python3.11/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pandasql) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pandasql) (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (from pandasql) (2.0.41)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->pandasql) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy->pandasql) (4.14.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)

# %% [markdown]
# # Part 1: basics
#
# This part is about converting natural language to SQL. It involves:
# - **Injecting key context about our dataset** into the system prompt so that the LLM can compose the query.
# - Calling an LLM via the OpenAI API
# - Parsing the LLM's output to isolate the SQL query

# %%
from rich import print
from openai import OpenAI
import pandas as pd
from pandasql import sqldf
from google.colab import userdata
api_key = userdata.get('OpenAI_API')

client = OpenAI(api_key=api_key)

# %%
# helper functions

def get_variable_name(df):
    for name, obj in globals().items():
        if obj is df:
            return name
    return None

def parse_query(query):
    if "```sql" in query:
        return query.replace("```sql", "").replace("```", "").strip()
    elif "```" in query:
        return query.replace("```", "").strip()
    else:
        return None

def get_query_from_prompt(prompt, data: pd.DataFrame,
                          N: int = 20):


    SYSTEM_PROMPT = f"""You are an SQL expert. Your job is to convert the natural language query into an SQL query for a dataset named {get_variable_name(data)} -- this should be the name you use in your query.

    Below, I will provide some descriptive statistics, as well as an overview of the first {N} rows of the dataset you are working with.

    Description:

    {data.describe().to_markdown()}

    Head (first {N} rows):

    {data.head(N).to_markdown()}
    """

    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": prompt},
        ],
        temperature=0.1,
    )

    return response.choices[0].message.content

# %%
with open("/content/sample_data/california_housing_test.csv") as f:
    df = pd.read_csv(f)

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %%
df.head(30).to_markdown()
# Out:
# '|    |   longitude |   latitude |   housing_median_age |   total_rooms |   total_bedrooms |   population |   households |   median_income |   median_house_value |\n|---:|------------:|-----------:|---------------------:|--------------:|-----------------:|-------------:|-------------:|----------------:|---------------------:|\n|  0 |     -122.05 |      37.37 |                   27 |          3885 |              661 |         1537 |          606 |          6.6085 |               344700 |\n|  1 |     -118.3  |      34.26 |                   43 |          1510 |              310 |          809 |          277 |          3.599  |               176500 |\n|  2 |     -117.81 |      33.78 |                   27 |          3589 |              507 |         1484 |          495 |          5.7934 |               270500 |\n|  3 |     -118.36 |      33.82 |                   28 |            67 |               15 |           49 |           11 |          6.1359 |               330000 |\n|  4 |     -119.67 |      36.33 |                   19 |          1241 |              244 |          850 |          237 |          2.9375 |                81700 |\n|  5 |     -119.56 |      36.51 |                   37 |          1018 |              213 |          663 |          204 |          1.6635 |                67000 |\n|  6 |     -121.43 |      38.63 |                   43 |          1009 |              225 |          604 |          218 |          1.6641 |                67000 |\n|  7 |     -120.65 |      35.48 |                   19 |          2310 |              471 |         1341 |          441 |          3.225  |               166900 |\n|  8 |     -122.84 |      38.4  |                   15 |          3080 |              617 |         1446 |          599 |          3.6696 |               194400 |\n|  9 |     -118.02 |      34.08 |                   31 |          2402 |              632 |         2830 |          603 |          2.3333 |               164200 |\n| 10 |     -118.24 |      33.98 |                   45 |           972 |              249 |         1288 |          261 |          2.2054 |               125000 |\n| 11 |     -119.12 |      35.85 |                   37 |           736 |              166 |          564 |          138 |          2.4167 |                58300 |\n| 12 |     -121.93 |      37.25 |                   36 |          1089 |              182 |          535 |          170 |          4.69   |               252600 |\n| 13 |     -117.03 |      32.97 |                   16 |          3936 |              694 |         1935 |          659 |          4.5625 |               231200 |\n| 14 |     -117.97 |      33.73 |                   27 |          2097 |              325 |         1217 |          331 |          5.7121 |               222500 |\n| 15 |     -117.99 |      33.81 |                   42 |           161 |               40 |          157 |           50 |          2.2    |               153100 |\n| 16 |     -120.81 |      37.53 |                   15 |           570 |              123 |          189 |          107 |          1.875  |               181300 |\n| 17 |     -121.2  |      38.69 |                   26 |          3077 |              607 |         1603 |          595 |          2.7174 |               137500 |\n| 18 |     -118.88 |      34.21 |                   26 |          1590 |              196 |          654 |          199 |          6.5851 |               300000 |\n| 19 |     -122.59 |      38.01 |                   35 |          8814 |             1307 |         3450 |         1258 |          6.1724 |               414300 |\n| 20 |     -122.15 |      37.75 |                   40 |          1445 |              256 |          849 |          255 |          3.8913 |               126300 |\n| 21 |     -121.37 |      38.68 |                   36 |          1775 |              296 |          937 |          305 |          3.1786 |                83400 |\n| 22 |     -118.16 |      34.07 |                   47 |        ...

# %%
test = """```sql
SELECT COUNT(*)
FROM dataset
WHERE median_income < 5;
```"""

res = parse_query(test)

print(res)
# Out:
# SELECT COUNT(*)
# FROM dataset
# WHERE median_income < 5;

# %%
query = "I want to see only the data where the median income is below 5?"

sql_query = get_query_from_prompt(query, df)
print(f"sql_query: {sql_query}")

parsed_query = parse_query(sql_query)
print(f"parsed_query: {parsed_query}")

run_query = lambda q: sqldf(q, globals())

result_df = run_query(parsed_query)

display(result_df)
# Out:
# sql_query: ```sql
# SELECT *
# FROM ___
# WHERE median_income < 5;
# ```
# parsed_query: SELECT *
# FROM ___
# WHERE median_income < 5;
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -118.30     34.26                43.0       1510.0           310.0
# 1       -119.67     36.33                19.0       1241.0           244.0
# 2       -119.56     36.51                37.0       1018.0           213.0
# 3       -121.43     38.63                43.0       1009.0           225.0
# 4       -120.65     35.48                19.0       2310.0           471.0
# ...         ...       ...                 ...          ...             ...
# 2383    -118.23     34.09                49.0       1638.0           456.0
# 2384    -119.86     34.42                23.0       1450.0           642.0
# 2385    -118.14     34.06                27.0       5257.0          1082.0
# 2386    -119.70     36.30                10.0        956.0           201.0
# 2387    -117.12     34.10                40.0         96.0            14.0
#
#       population  households  median_income  median_house_value
# 0          809.0       277.0         3.5990            176500.0
# 1          850.0       237.0         2.9375             81700.0
# 2          663.0       204.0         1.6635             67000.0
# 3          604.0       218.0         1.6641             67000.0
# 4         1341.0       441.0         3.2250            166900.0
# ...          ...         ...            ...                 ...
# 2383      1500.0       430.0         2.6923            150000.0
# 2384      1258.0       607.0         1.1790            225000.0
# 2385      3496.0      1036.0         3.3906            237200.0
# 2386       693.0       220.0         2.2895             62000.0
# 2387        46.0        14.0         3.2708            162500.0
#
# [2388 rows x 9 columns]

# %% [markdown]
# # Part 2: Makstat
#
# Now we escalate onto working with an actual MAKSTAT dataset, including:
#
# - POST request to fetch the data
# - Grappling with the .px data format

# %%
import requests
import json

URL = "https://makstat.stat.gov.mk:443/PXWeb/api/v1/mk/MakStat/DelovniSubj/DemografijaNaPretprijatija/DelovniTekovniPodatoci/350_DelSub_Mk_02_ml.px"

query = {
  "query": [
    {
      "code": "Година",
      "selection": {
        "filter": "item",
        "values": [
          "2023"
        ]
      }
    },
    {
      "code": "Мерки",
      "selection": {
        "filter": "item",
        "values": [
          "1"
        ]
      }
    }
  ],
  "response": {
    "format": "px"
  }
}

response = requests.post(URL, json=query)

# Check if the request was successful
if response.status_code == 200:
    print("Request successful!")
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# Request successful!

# %%
from pyaxis import pyaxis

with open("result.px", 'wb') as f:
    f.write(response.content)

result = pyaxis.parse('result.px', encoding='utf-8')#, 'ISO-8859-5')
# Out:
# Multilingual PX file

# %%
print(result['DATA'])
# Out:
#                               Дејност Година                  Мерки  \
# 0                              Вкупно   2023  Активни претпријатија
# 1                              Вкупно   2023  Активни претпријатија
# 2                              Вкупно   2023  Активни претпријатија
# 3                              Вкупно   2023  Активни претпријатија
# 4                              Вкупно   2023  Активни претпријатија
# ..                                ...    ...                    ...
# 635  O96 Други лични услужни дејности   2023  Активни претпријатија
# 636  O96 Други лични услужни дејности   2023  Активни претпријатија
# 637  O96 Други лични услужни дејности   2023  Активни претпријатија
# 638  O96 Други лични услужни дејности   2023  Активни претпријатија
# 639  O96 Други лични услужни дејности   2023  Активни претпријатија
#
#                   Големина   DATA
# 0                   Вкупно  67482
# 1              0 вработени   5405
# 2          1 - 4 вработени  49906
# 3          5 - 9 вработени   6400
# 4    10 и повеќе вработени   5771
# ..                     ...    ...
# 635                 Вкупно   2060
# 636            0 вработени     80
# 637        1 - 4 вработени   1881
# 638        5 - 9 вработени     74
# 639  10 и повеќе вработени     25
#
# [640 rows x 5 columns]

# %%
makstat = pd.DataFrame(result['DATA'])

# %%
makstat
# Out:
#                               Дејност Година                  Мерки  \
# 0                              Вкупно   2023  Активни претпријатија
# 1                              Вкупно   2023  Активни претпријатија
# 2                              Вкупно   2023  Активни претпријатија
# 3                              Вкупно   2023  Активни претпријатија
# 4                              Вкупно   2023  Активни претпријатија
# ..                                ...    ...                    ...
# 635  O96 Други лични услужни дејности   2023  Активни претпријатија
# 636  O96 Други лични услужни дејности   2023  Активни претпријатија
# 637  O96 Други лични услужни дејности   2023  Активни претпријатија
# 638  O96 Други лични услужни дејности   2023  Активни претпријатија
# 639  O96 Други лични услужни дејности   2023  Активни претпријатија
#
#                   Големина   DATA
# 0                   Вкупно  67482
# 1              0 вработени   5405
# 2          1 - 4 вработени  49906
# 3          5 - 9 вработени   6400
# 4    10 и повеќе вработени   5771
# ..                     ...    ...
# 635                 Вкупно   2060
# 636            0 вработени     80
# 637        1 - 4 вработени   1881
# 638        5 - 9 вработени     74
# 639  10 и повеќе вработени     25
#
# [640 rows x 5 columns]

# %%
makstat.describe()
# Out:
#        Дејност Година                  Мерки Големина DATA
# count      640    640                    640      640  640
# unique     128      1                      1        5  310
# top     Вкупно   2023  Активни претпријатија   Вкупно    2
# freq         5    640                    640      128   27

# %%
makstat.head(20)
# Out:
#                                               Дејност Година  \
# 0                                              Вкупно   2023
# 1                                              Вкупно   2023
# 2                                              Вкупно   2023
# 3                                              Вкупно   2023
# 4                                              Вкупно   2023
# 5                       Б Рударство и вадење на камен   2023
# 6                       Б Рударство и вадење на камен   2023
# 7                       Б Рударство и вадење на камен   2023
# 8                       Б Рударство и вадење на камен   2023
# 9                       Б Рударство и вадење на камен   2023
# 10                        В Преработувачка индустрија   2023
# 11                        В Преработувачка индустрија   2023
# 12                        В Преработувачка индустрија   2023
# 13                        В Преработувачка индустрија   2023
# 14                        В Преработувачка индустрија   2023
# 15  В10_В12 Производство на прехранбени производи;...   2023
# 16  В10_В12 Производство на прехранбени производи;...   2023
# 17  В10_В12 Производство на прехранбени производи;...   2023
# 18  В10_В12 Производство на прехранбени производи;...   2023
# 19  В10_В12 Производство на прехранбени производи;...   2023
#
#                     Мерки               Големина   DATA
# 0   Активни претпријатија                 Вкупно  67482
# 1   Активни претпријатија            0 вработени   5405
# 2   Активни претпријатија        1 - 4 вработени  49906
# 3   Активни претпријатија        5 - 9 вработени   6400
# 4   Активни претпријатија  10 и повеќе вработени   5771
# 5   Активни претпријатија                 Вкупно    191
# 6   Активни претпријатија            0 вработени     25
# 7   Активни претпријатија        1 - 4 вработени     91
# 8   Активни претпријатија        5 - 9 вработени     33
# 9   Активни претпријатија  10 и повеќе вработени     42
# 10  Активни претпријатија                 Вкупно   7810
# 11  Активни претпријатија            0 вработени    497
# 12  Активни претпријатија        1 - 4 вработени   5118
# 13  Активни претпријатија        5 - 9 вработени    830
# 14  Активни претпријатија  10 и повеќе вработени   1365
# 15  Активни претпријатија                 Вкупно   1794
# 16  Активни претпријатија            0 вработени     93
# 17  Активни претпријатија        1 - 4 вработени   1133
# 18  Активни претпријатија        5 - 9 вработени    230
# 19  Активни претпријатија  10 и повеќе вработени    338

# %%
makstat.head(20).to_markdown()
# Out:
# '|    | Дејност                                                                     |   Година | Мерки                 | Големина              |   DATA |\n|---:|:----------------------------------------------------------------------------|---------:|:----------------------|:----------------------|-------:|\n|  0 | Вкупно                                                                      |     2023 | Активни претпријатија | Вкупно                |  67482 |\n|  1 | Вкупно                                                                      |     2023 | Активни претпријатија | 0 вработени           |   5405 |\n|  2 | Вкупно                                                                      |     2023 | Активни претпријатија | 1 - 4 вработени       |  49906 |\n|  3 | Вкупно                                                                      |     2023 | Активни претпријатија | 5 - 9 вработени       |   6400 |\n|  4 | Вкупно                                                                      |     2023 | Активни претпријатија | 10 и повеќе вработени |   5771 |\n|  5 | Б Рударство и вадење на камен                                               |     2023 | Активни претпријатија | Вкупно                |    191 |\n|  6 | Б Рударство и вадење на камен                                               |     2023 | Активни претпријатија | 0 вработени           |     25 |\n|  7 | Б Рударство и вадење на камен                                               |     2023 | Активни претпријатија | 1 - 4 вработени       |     91 |\n|  8 | Б Рударство и вадење на камен                                               |     2023 | Активни претпријатија | 5 - 9 вработени       |     33 |\n|  9 | Б Рударство и вадење на камен                                               |     2023 | Активни претпријатија | 10 и повеќе вработени |     42 |\n| 10 | В Преработувачка индустрија                                                 |     2023 | Активни претпријатија | Вкупно                |   7810 |\n| 11 | В Преработувачка индустрија                                                 |     2023 | Активни претпријатија | 0 вработени           |    497 |\n| 12 | В Преработувачка индустрија                                                 |     2023 | Активни претпријатија | 1 - 4 вработени       |   5118 |\n| 13 | В Преработувачка индустрија                                                 |     2023 | Активни претпријатија | 5 - 9 вработени       |    830 |\n| 14 | В Преработувачка индустрија                                                 |     2023 | Активни претпријатија | 10 и повеќе вработени |   1365 |\n| 15 | В10_В12 Производство на прехранбени производи;пијалаци и тутунски производи |     2023 | Активни претпријатија | Вкупно                |   1794 |\n| 16 | В10_В12 Производство на прехранбени производи;пијалаци и тутунски производи |     2023 | Активни претпријатија | 0 вработени           |     93 |\n| 17 | В10_В12 Производство на прехранбени производи;пијалаци и тутунски производи |     2023 | Активни претпријатија | 1 - 4 вработени       |   1133 |\n| 18 | В10_В12 Производство на прехранбени производи;пијалаци и тутунски производи |     2023 | Активни претпријатија | 5 - 9 вработени       |    230 |\n| 19 | В10_В12 Производство на прехранбени производи;пијалаци и тутунски производи |     2023 | Активни претпријатија | 10 и повеќе вработени |    338 |'

# %%
query = "Колку вкупно активни претпријатија имало во 2023 година во преработувачката индустрија?"

sql_query = get_query_from_prompt(query, makstat)
parsed_query = parse_query(sql_query)
print(f"parsed_query: {parsed_query}")

run_query = lambda q: sqldf(q, globals())

result_df = run_query(parsed_query)

display(result_df)
# Out:
# parsed_query: SELECT DATA
# FROM makstat
# WHERE Дејност = 'В Преработувачка индустрија'
#   AND Година = 2023
#   AND Мерки = 'Активни претпријатија'
#   AND Големина = 'Вкупно';
#    DATA
# 0  7810

# %% [markdown]
# The answer is correct!
#
# This example, of course, relies on the relevant key ("преработувачка индустрија") being present in the head() overview. This will not always be the case. Think about ways to show the LLM all the relevant categories that it can query.

# %% [markdown]
# # Part 3: which dataset?
#
# A significant part of the challenge will be enabling the LLM to decide which dataset to query via the API with what parameters at first. More next time!
