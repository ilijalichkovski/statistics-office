# %% [markdown]
# # Дел 1: пребарување на Макстат

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

MAKSTAT_URL = "https://makstat.stat.gov.mk/PXWeb/pxweb/mk/MakStat/search"

# %% [markdown]
# Основна функција за пребарување:

# %%
def keyword_search(keyword):
    params = {
        "searchquery": keyword
    }
    r = requests.get(MAKSTAT_URL, params=params)
    r.raise_for_status()
    return r.text   # HTML

if __name__ == "__main__":
    html = keyword_search("население")
    soup = BeautifulSoup(html, "html.parser")
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="mk">
#  <head>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    База на податоци МАКСТАТ
#   </title>
#   <link href="/PXWeb/Resources/Styles/reset.css?v=22.1.0.23905" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/PXWeb/Resources/Styles/main-common.css?v=22.1.0.23905" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/PXWeb/Resources/Styles/main-pxweb.css?v=22.1.0.23905" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/PXWeb/Resources/Styles/jQuery/redmond/jquery-ui.css?v=22.1.0.23905" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/PXWeb/Resources/Styles/jQuery/tablesorter/style.css?v=22.1.0.23905" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/PXWeb/Resources/Styles/main-custom.css?v=22.1.0.23905" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="/PXWeb/Resources/Scripts/jquery-3.5.1.min.js?v=22.1.0.23905">
#   </script>
#   <script src="/PXWeb/Resources/Scripts/jquery-ui.min.js?v=22.1.0.23905">
#   </script>
#   <script src="/PXWeb/Resources/Scripts/pcaxis.web.client.js?v=22.1.0.23905">
#   </script>
#   <script src="/PXWeb/Resources/Scripts/pcaxis.web.controls.js?v=22.1.0.23905">
#   </script>
#   <script src="/PXWeb/Resources/Scripts/jquery.tablesorter.min.js?v=22.1.0.23905">
#   </script>
#   <script src="/PXWeb/Resources/Scripts/jquery.metadata.js?v=22.1.0.23905">
#   </script>
#   <script src="/PXWeb/Resources/Scripts/format.20110630-1100.min.js?v=22.1.0.23905">
#   </script>
#  </head>
#  <body>
#   <div id="pxwebcontent">
#    <form action="./search?searchquery=%u043d%u0430%u0441%u0435%u043b%u0435%u043d%u0438%u0435" id="aspnetForm" method="post">
#     <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#     <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="140167E6"/>
#     <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value=""/>
#     <a class="top-link pxweb-btn negative hide" href="javascript:__doPostBack('ctl00$ToTheTopButton','')" id="ctl00_ToTheTopButton">
#      <svg class="icon-top-link-button" fill="none" height="32" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="40">
#       <circle cx="12" cy="12" r="10">
#       </circle>
#       <polyline points="16 12 12 8 8 12">
#       </polyline>
#       <line x1="12" x2="12" y1="16" y2="8">
#       </line>
#      </svg>
#      Кон почеток
#     </a>
#     <div id="wrap">
#      <header id="header">
#       <div class="header flex-row flex-wrap justify-space-between">
#        <a aria-label="Press enter to go directly to main content" class="screenreader-only pxweb-link" href="#pxcontent" id="ctl00_SkipToMain">
#         Jump to main content
#        </a>
#        <div class="headerleft flex-row">
#         <a href="/PXWeb/pxweb/mk/" id="ctl00_LogoLink">
#          <img alt="PxWeb Logotype" class="imgSiteLogo" id="ctl00_imgSiteLogo" src="../../../Resources/Images/Logo-MakStat.png"/>
#         </a>
#         <span class="siteLogoText">
#          База на податоци МАКСТАТ
#         </span>
#        </div>
#        <div class="headerright">
#         <div class="px-change-lang-div flex-column">
#          <div class="pxweb-link">
#           <a class="px-change-lang" href="/PXWeb/pxweb/en/MakStat/">
#            <span class="link-text px-change-lang" lang="en">
#             English
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </header>
#      <div id="ctl00_breadcrumb1">
#       <nav aria-label="breadcrumb" id="breadcrumb">
#        <a href="/PXWeb/pxweb/mk/" id="ctl00_breadcrumb1_breadcrumb1_lnkHome">
#         <img alt="Icon representing home" class="breadcrumb_homebutton" id="ctl00_breadcrumb1_breadcrumb1_imgHome" src="/PXWeb/WebResource.axd?d=e_C1zbYQ73YY4Ro6OXjYJ8A79tHYCibRneBxsMqUTs5iIhrgJJIWB_qPjr-4GhowD561TAnW2vp7NoPSB0FsQxD3ByFQpL67Hb8h4aDnQNXxhN0oVF38-hgCvYE0ZHMdSzSRzpBryB4L8oyh9iGGpQ2&amp;t=638016138440000000" title="Home"/>
#        </a>
#        <span class="breadcrumb_sep" id="ctl00_breadcrumb1_breadcrumb1_lblSep1">
#         /
#        </span>
#        <a class="pxweb-link breadcrumb_text" href="/PXWeb/pxweb/mk/MakStat/" id="ctl00_breadcrumb1_breadcrumb1_lnkDb">
#         База на податоци МАКСТАТ
#        </a>
#        <span class="breadcrumb_sep" id="ctl00_breadcrumb1_breadcrumb1_lblSepBeforeSubPage">
#         /
#        </span>
#        <span class="breadcrumb_text_nolink breadcrumb_subpage" id="ctl00_breadcrumb1_breadcrumb1_lblSubPage">
#         Search
#        </span>
#       </nav>
#      </div>
#      <main id="place-holder">
#       <h1 class="h1title" id="ctl00_lblH1Title">
#        База на податоци МАКСТАТ
#       </h1>
#       <div id="ctl00_navigationFlowControl">
#        <section aria-label="Overview of the three steps in the process to get the data.">
#         <span class="screenreader-only" id="ctl00_navigationFlowControl_navigationFlowControl_ExplainAriaLabel">
#          The 3 steps are Choose table, Choose variable and Show result. You are currently at Избери табела
#         </span>
#         <div id="navigationFlow">
#          <div class="navigationFlowArea flex-row justify-center align-flex-start">
#           <a aria-hidden="true" aria-label="Back to Choose table" class="flex-column justify-space-between align-center navigation-link first active" id="ctl00_navigationFlowControl_navigationFlowControl_firstStepLink">
#            <img alt="" aria-hidden="true" class="nav-pic" id="ctl00_navigationFlowControl_navigationFlowControl_firstStepImage" src="../../../Resources/Images/svg/NavigationFlow/Step1_active.svg"/>
#            <span class="pxweb-link header nav-step first active" id="ctl00_navigationFlowControl_navigationFlowControl_firstStepLabel">
#             Избери табела
#            </span>
#           </a>
#           <hr aria-hidden="true" class="nav-hr-left mk"/>
#           <a aria-hidden="true" aria-label="Back to Choose variable" class="flex-column justify-space-between align-center navigation-link future" id="ctl00_navigationFlowControl_navigationFlowControl_secondStepLink">
#            <img alt="" aria-hidden="true" class="nav-pic" id="ctl00_navigationFlowControl_navigationFlowControl_secondStepImage" src="../../../Resources/Images/svg/NavigationFlow/Step2_future.svg"/>
#            <span class="pxweb-link header nav-step second future" id="ctl00_navigationFlowControl_navigationFlowControl_secondStepLabel">
#             Избери променлива
#            </span>
#           </a>
#           <hr aria-hidden="true" class="nav-hr-right mk"/>
#           <a aria-hidden="true" class="flex-column justify-space-between align-center third navigation-link future" id="ctl00_navigationFlowControl_navigationFlowControl_thirdStepLink">
#            <img alt="" aria-hidden="true" class="nav-pic" id="ctl00_navigationFlowControl_navigationFlowControl_thirdStepImage" src="../../../Resources/Images/svg/NavigationFlow/Step3_future.svg"/>
#            <span class="nav-step third future" id="ctl00_navigationFlowControl_navigationFlowControl_thirdStepLabel">
#             Прикажи табела
#            </span>
#           </a>
#          </div>
#         </div>
#        </section>
#       </div>
#       <div id="table-title">
#        <div id="place-holder-title">
#        </div>
#       </div>
#       <div id="pxcontent">
#       </div>
#       <div class="searchTopLeftContent">
#        <div class="search_container">
#         <div class="search_panel" id="ctl00_ContentPlaceHolderMain_pxSearch_pnlSearch">
#          <label class="search_label" for="ctl00_ContentPlaceHolderMain_pxSearch_txtSearch" id="ctl00_ContentPlaceHolderMain_pxSearch_lblSearch">
#           Пребарај во База на податоци МАКСТАТ:
#          </label>
#          <input class="search_textbox" id="ctl00_ContentPlaceHolderMain_pxSearch_txtSearch" name="ctl00$ContentPlaceHolderMain$pxSearch$txtSearch" type="text" value="население"/>
#          <input class="search_button savequery_create" id="ctl00_ContentPlaceHolderMain_pxSearch_cmdSearch" name="ctl00$ContentPlaceHolderMain$pxSearch$cmdSearch" type="submit" value="Пребарај"/>
#          <span class="search_error" id="ctl00_ContentPlaceHolderMain_pxSearch_lblError">
#          </span>
#          <input id="ctl00_ContentPlaceHolderMain_pxSearch_hidRedirect" name="ctl00$ContentPlaceHolderMain$pxSearch$hidRedirect" type="hidden" value="False"/>
#         </div>
#        </div>
#       </div>
#       <div class="break">
#       </div>
#       <div class="search-settings" id="ctl00_ContentPlaceHolderMain_pnlSearch">
#        <input checked="checked" id="ctl00_ContentPlaceHolderMain_rbAll" name="ctl00$ContentPlaceHolderMain$searchOptions" type="radio" value="all"/>
#        <label for="ctl00_ContentPlaceHolderMain_rbAll">
#         Пребарај ги сите полиња
#        </label>
#        <input id="ctl00_ContentPlaceHolderMain_rbSelect" name="ctl00$ContentPlaceHolderMain$searchOptions" type="radio" value="select"/>
#        <label for="ctl00_ContentPlaceHolderMain_rbSelect">
#         Пребарај само
#        </label>
#        <span class="aspNetDisabled search-option">
#         <input disabled="disabled" id="ctl00_ContentPlaceHolderMain_chkTitle" name="ctl00$ContentPlaceHolderMain$chkTitle" type="checkbox"/>
#         <label for="ctl00_ContentPlaceHolderMain_chkTitle">
#          Наслов на табелата
#         </label>
#        </span>
#        <span class="aspNetDisabled search-option">
#         <input disabled="disabled" id="ctl00_ContentPlaceHolderMain_chkValues" name="ctl00$ContentPlaceHolderMain$chkValues" type="checkbox"/>
#         <label for="ctl00_ContentPlaceHolderMain_chkValues">
#          текстот
#         </label>
#        </span>
#        <span class="aspNetDisabled search-option">
#         <input disabled="disabled" id="ctl00_ContentPlaceHolderMain_chkCodes" name="ctl00$ContentPlaceHolderMain$chkCodes" type="checkbox"/>
#         <label for="ctl00_ContentPlaceHolderMain_chkCodes">
#          код
#         </label>
#        </span>
#       </div>
#       <span class="search_searchresulttext" id="ctl00_ContentPlaceHolderMain_lblSearchResult">
#        Резултати од пребарувањето: (145 редови)
#       </span>
#       <table cellspacing="0" class="searchResultTable">
#        <thead>
#         <tr>
#          <td class="searchHeaderCell searchCellTable">
#           Табела
#          </td>
#          <td class="searchHeaderCell searchCellPublished">
#           Објавена
#          </td>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__PopisNaNaselenie__PopisOpstini/01Popis_op_02_VkNasDomSt_mk.px/">
#            Вкупно население, домаќинства и станови во Република Македонија, Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           07.9.2010
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__PopisNaNaselenie__PopisOpstini/03Popis_op_02_VkNasPoNacPr_mk.px/">
#            Вкупно население според изјаснување по национална припадност, Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           08.4.2010
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__NeaktivnoNaselenie/052_PazTrud_Mk_NeaNasPoKatVoz_ml.px/">
#            Неактивно население по категории и по возраст, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__NeaktivnoNaselenieArhiva/052_PazTrud_Mk_NeaNasPoKatVoz_ml_arh.px/">
#            Неактивно население по категории и по возраст, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__TrimesecniARS/450_PazTrud_Mk_ActObr_ml.px/">
#            Активно население според школската подготовка, по пол, тримесечно
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           05.9.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__PopisNaNaselenie__PopisOpstini/04Popis_op_02_VkNasNaVozr10-PolPism_mk.px/">
#            Вкупно население на возраст од 10 години и повеќе според пол и писменост, Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           08.4.2010
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__PopisNaNaselenie__PopisOpstini/06Popis_op_02_VkNasNaVozr15-SporAkt_mk.px/">
#            Вкупно население во земјата на возраст од 15 години и повеќе, според активноста, Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           08.4.2010
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/002_PazTrud_Mk_rabotosposobno2_ml.px/">
#            Работоспособно население според економската активност, полот и школската подготовка, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/002_PazTrud_Mk_rabotosposobno2_ml_arh.px/">
#            Работоспособно население според економската активност, полот и школската подготовка, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__EkonomskiKarakteristiki/T1060P21.px/">
#            Неактивно население над 15 години, по возрасни групи, пол и општини, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           02.12.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__EkonomskiKarakteristiki/T1034P21.px/">
#            Вкупно работоспособно население на  возраст од 15 и повеќе  според возраст, пол  и економската  активност, по општини, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           01.6.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__StapkiDrugiIndikatoriArhiva/625_PazTrud_Mk_0ActNas_ml_arh.px/">
#            Активно население според пол и стапки на активност, по тримесечја, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__Demografija/T1057P21.px/">
#            Вкупно автохтоно и доселено  население  по возраст, по пол, по општини, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.9.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__AnketaZaObrazovanieVozrasni/022_PazTru_Ml_ProsBr_ml.px/">
#            Просечен број на часови поминати во образование и обука, според економската активност, по пол
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           15.1.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__PolindikatorNaselenie/999_PoloviStatistikiNas_ml.px/">
#            Показатели од половите статистики - Население
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           29.8.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/080_PazTrud_Mk_RabNas_ml.px/">
#            Работоспособно население според економската активност и возраста, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/001_PazTrud_Mk_rabotosposobno1_ml.px/">
#            Работоспособно население според економската активност, полот и возраста, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/058_PazTrud_Mk_Urban_ml.px/">
#            Работоспособно население според економската активност, полот и возраста - урбан дел, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/059_PazTrud_Mk_Rural_ml.px/">
#            Работоспособно население според економската активност, полот и возраста, рурален дел, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/058_PazTrud_Mk_Urban_ml_arh.px/">
#            Работоспособно население според економската активност, полот и возраста - урбан дел, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/059_PazTrud_Mk_Rural_ml_arh.px/">
#            Работоспособно население според економската активност, полот и возраста, рурален дел, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/080_PazTrud_Mk_RabNas_ml_arh.px/">
#            Работоспособно население според економската активност и возраста, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/068_RabotSpos_EkonAkt_Pol_UceForObr_Step_ml.px/">
#            Работоспособно население според економската активност, пол и учеството во формалното (редовно) образование, степенот на образование, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/068_RabotSpos_EkonAkt_Pol_UceForObr_Step_ml_arh.px/">
#            Работоспособно население според економската активност, пол и учеството во формалното (редовно) образование, степенот на образование, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/003_PazTrud_Mk_rabotosposobno3_ml.px/">
#            Работоспособно население според економската активност, полот и брачната состојба, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/001_PazTrud_Mk_rabotosposobno1_ml_arh.px/">
#            Работоспособно население според економската активност, полот и возраста, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/003_PazTrud_Mk_rabotosposobno3_ml_arh.px/">
#            Работоспособно население според економската активност, полот и брачната состојба, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/073_RabSpos_NadvorObrSis_EkonAkt_pol_ml.px/">
#            Работоспособно население според учеството во образовни активности надвор од редовниот образовен систем според економската активност, пол, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/073_RabSpos_NadvorObrSis_EkonAkt_pol_ml_arh.px/">
#            Работоспособно население според учеството во образовни активности надвор од редовниот образовен систем според економската активност, пол, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/062_RabSpos_EkonAkt_Pol_SkolPodg_Urban_ml.px/">
#            Работоспособно население според економската активност, пол, школската подготовка, урбан дел, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/063_RabotNasel_EkonAkt_Pol_SkolPod_Rural_ml.px/">
#            Работоспособно население според економската активност, пол, школската подготовка, рурален дел, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__TrimesecniARS/300_PazTrud_Mk_RabSpos_ml.px/">
#            Работоспособно население според економската активност, по возрасни групи и по пол, тримесечно
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           05.9.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/062_RabSpos_EkonAkt_Pol_SkolPodg_Urban_ml_arh.px/">
#            Работоспособно население според економската активност, пол, школската подготовка, урбан дел, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/063_RabotNasel_EkonAkt_Pol_SkolPod_Rural_ml_arh.px/">
#            Работоспособно население според економската активност, пол, школската подготовка, рурален дел, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__AktivnoNaselenie__Nevraboteni/057_PazTrud_Mk_LicaNeRabINeUcat_ml.px/">
#            Лица на возраст од 15 до 19 години кои не се вработени и кои не се вклучени во процесот на образование или обука, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__AktivnoNaselenie_A__NevraboteniArhiva/057_PazTrud_Mk_LicaNeRabINeUcat_ml_arh.px/">
#            Лица на возраст од 15 до 19 години кои не се вработени и кои не се вклучени во процесот на образование или обука, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/075_RabSpos_EkoAkt_Pol_VretraObrAkt_ml.px/">
#            Работоспособно население според економската активност, пол и времетраењето на образовните активности надвор од редовниот образовен систем, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/075_RabSpos_EkoAkt_Pol_VretraObrAkt_ml_arh.px/">
#            Работоспособно население според економската активност, пол и времетраењето на образовните активности надвор од редовниот образовен систем, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/078_RabSpos_NadvObrSis_EkonAkt_ml.px/">
#            Работоспособно население кое учествува во образовни активности надвор од редовниот образовен систем, според економската активност и причините за учество, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/078_RabSpos_NadvObrSis_EkonAkt_ml_arh.px/">
#            Работоспособно население кое учествува во образовни активности надвор од редовниот образовен систем, според економската активност и причините за учество, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieSet/T1008P21a.px/">
#            Вкупно попишани, вкупно резидентно население и вкупно нерезидентно население, според етничката припадност и пол, по општини- Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           01.4.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieSet/T1001P21.px/">
#            Вкупно резидентно население, домаќинства и станови во Република Северна Македонија, по општини, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.3.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/079_Rabs_NadvObr_EkonAkt_Urban_Rural_Pricini_ml.px/">
#            Работоспособно население кое учествува во образовни активности надвор од редовниот образовен систем, според економската активност, пол, урбан и рурален дел и причините за учество, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/079_Rabs_NadvObr_EkonAkt_Urban_Rural_Pricini_ml_arh.px/">
#            Работоспособно население кое учествува во образовни активности надвор од редовниот образовен систем, според економската активност, пол, урбан и рурален дел и причините за учество, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__AnketaZaObrazovanieVozrasni/032_PazTru_Ml_LicaStran_ml.px/">
#            Лица кои познаваат најмалку еден странски јазик (самостојна изјава), според економската активност, по возраст
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           15.1.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__Polindikatori_PazarNaTrud/999_PoloviStatistikiARS_ml.px/">
#            Показатели од половите статистики - Работна сила
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           24.8.2023
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__Polindikatori_PazarNaTrud/999_PoloviStatistikiARS_revizia_ml.px/">
#            Показатели од половите статистики - Ревизија
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           18.8.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/300_OdrzRaz_Mk_SDG_08_Decentwork_ml.px/">
#            ЦОР 8 Достоинствена работа и економски раст
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2002Arhiva/275_Popis_RM_NasPolStar31_02_mk.px/">
#            Население по возраст и по пол, според пописите
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           13.7.2018
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/004_PazTrud_Mk_rabotosposobno4_ml.px/">
#            Работоспособно население според брачната состојба, полот и возраста, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/005_PazTrud_Mk_rabotosposobno5_ml.px/">
#            Работоспособно население според возрастa и школската подготовка, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__NeaktivnoNaselenie/051_PazTrud_Mk_Neaktiv_ml.px/">
#            Неактивно население според школската подготовка и возраста, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__ObrazovanieNauka__OsnovnoObrazovanie__OsnovnoPocetokUcebna/250_osnucil_mk_pocT4_ml.px/">
#            Стапки на запишување во основно образование, по пол, по учебна година
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           06.8.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__ObrazovanieNauka__SrednoObrazovanie__SrednoPocetokUcebna/250_sreducil_rsm_poc_t4_ml.px/">
#            Стапки на запишување во средно образование, по пол, по учебна година
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           06.8.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__AnketaZaObrazovanieVozrasni/004_PazTrud_Mk_LicObrzDozUc_ml.px/">
#            Лица кои посетуваат образование и доживотно учење според економската активност, по возараст
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           15.1.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__AnketaZaObrazovanieVozrasni/005_PazTrud_Mk_LicapostobrzVozSpEkoAktUrbRur_ml.px/">
#            Лица кои посетуваат образование и доживотно учење според економската активност, урбан и рурален дел
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           15.1.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/225_OdrzRaz_Mk_SDG_05_Gender_ml.px/">
#            ЦОР 5 Родова рамноправност
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PoloviStat/125_PoloviStatistiki_ml.px/">
#            Показатели од половите статистики во Република Македонија
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           03.6.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__PodatociNaselenie/T1501P21.px/">
#            Вкупно резидентно население, домаќинства и станови во Република Северна Македонија по населени места, Попис , 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           24.7.2023
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/200_OdrzRaz_Mk_SDG_04_Education_ml.px/">
#            ЦОР 4. Квалитетно образование
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/250_OdrzRaz_Mk_SDG_06_Cleanwater_ml.px/">
#            ЦОР 6. Чиста вода и санитација
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__StapkiDrugiIndikatori/006_PazTrud_Mk_aktivnost_ml.px/">
#            Стапки на активност на населението на возраст од 15 години и повеќе според полот и возраста, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__StapkiDrugiIndikatoriArhiva/006_PazTrud_Mk_aktivnost_ml_arh.px/">
#            Стапки на активност на населението на возраст од 15 години и повеќе според полот и возраста, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni30Juni/30062021_MKD_Za_PX.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, состојба 30 јуни
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.6.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni30Juni/30062021_Ops_Za_PX.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, по општини, состојба 30 јуни
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.6.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni30Juni/30062021_Reg_Za_PX.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, по региони, состојба 30 јуни
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.6.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni31Dekemvri/31122021_MKD_Za_PX.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, состојба 31 декември
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.6.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni31Dekemvri/31122021_Ops_Za_PX.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, по општина, состојба 31 декември
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.6.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni31Dekemvri/31122021_Reg_Za_PX.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, по регион, состојба 31 декември
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.6.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/070_RabSpos_RedObr_Stepen_Vozr_ml.px/">
#            Работоспособно население кое посетува редовно образование, според степенот на образование и возраста, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/071_RabSpos_RedObr_Pol_Pole_ml.px/">
#            Работоспособно население кое посетува редовно образование, според пол и полето на образование, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/004_PazTrud_Mk_rabotosposobno4_ml_arh.px/">
#            Работоспособно население според брачната состојба, полот и возраста, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/005_PazTrud_Mk_rabotosposobno5_ml_arh.px/">
#            Работоспособно население според возрастa и школската подготовка, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/070_RabSpos_RedObr_Stepen_Vozr_ml_arh.px/">
#            Работоспособно население кое посетува редовно образование, според степенот на образование и возраста, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/071_RabSpos_RedObr_Pol_Pole_ml_arh.px/">
#            Работоспособно население кое посетува редовно образование, според пол и полето на образование, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__NeaktivnoNaselenieArhiva/051_PazTrud_Mk_Neaktiv_ml_arh.px/">
#            Неактивно население според школската подготовка и возраста, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__PopisNaNaselenie__PopisOpstini/02Popis_op_02_VkNasPoVozrGrPol_mk.px/">
#            Вкупно население на Република Македонија според петгодишни групи на возраст, по пол, Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           10.2.2016
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__PopisNaNaselenie__PopisOpstini/05Popis_op_02_VkNasNaVozr15-SkolPod_mk.px/">
#            Вкупно население на возраст од 15 и повеќе години, според школска подготовка, Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           08.4.2010
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__VozrastiPol/T1017P21.px/">
#            Вкупно резидентно население по поединечни години на возраст и по пол, по региони, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           29.4.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__VozrastiPol/T1018P21.px/">
#            Вкупно резидентно население  според 5-годишни возрасни групи и  пол, по региони, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           29.4.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__VozrastiPol/T1020P21.px/">
#            Вкупно резидентно  население  според поединечни години на  возраст и  пол, по општини, Попис , 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           29.4.2022
#          </td>
# ...
#           01.6.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieSet/T1002P21.px/">
#            Вкупно резидентно население во Република Северна Македонија по поединечни години на возраст и по пол, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.3.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieSet/T1003P21.px/">
#            Вкупно резидентно население во Република Северна Македонија по 5-годишни возрасни групи и по пол, по општини, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.3.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieSet/T1016P21.px/">
#            Вкупно резидентно население во Република Северна Македонија според јазикот кој вообичаено се зборува во домаќинството, по пол, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.3.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/475_OdrzRaz_Mk_SDG_16_Peace_ml.px/">
#            ЦОР 16 Мир, правда и силни институции
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/325_OdrzRaz_Mk_SDG_09_Industry_ml.px/">
#            ЦОР 9. Индустрија, иновација инфраструктура
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni2003_2020Revidirani/175_ProcNasReg01_ml.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, по региони, состојба 1 јануари, ревидирани податоци за периодот 2017 - 2021, според Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           09.11.2023
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2021__Proceni2003_2020Revidirani/200_ProcNasReg30_ml.px/">
#            Вкупно проценето резидентно население на Република Северна Македонија, по региони, состојба 30 јуни, ревидирани податоци за периодот 2017 - 2020 според Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           09.11.2023
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2002Arhiva/124_Popis_Ops80_NasPolStar3006_mk.px/">
#            Население во Република Македонија на 30.06 по специфични групи на возраст, по пол, по општини, по години, според промените во територијалната поделба од 2014 година, според Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           25.6.2021
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2002Arhiva/126_Popis_Ops80_NasPolStar3112_mk.px/">
#            Население во Република Македонија на 31.12 по специфични групи на возраст, по пол, по општини, според промените во територијалната поделба во 2014 год., по години, според Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           25.6.2021
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2002Arhiva/174_Popis_Ops84_NasPolStar3006_mk.px/">
#            Население во Република Македонија на 30.06 по специфични групи на возраст, по пол, по општини, според територијалната поделба од 2004год., по години, според Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           13.7.2018
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2002Arhiva/175_Popis_Ops124_NasPolStar3006_mk.px/">
#            Население во Република Македонија на 30.06 по специфични групи на возраст, по пол, по општини според територијалната поделба од 1996 год., по години, според Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           13.7.2018
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__ProcenkiNaselenie__ProcenkiPopis2002Arhiva/225_Popis_reg_3112_PolVoz_mk.px/">
#            Население во Република Македонија на 31.12, по пол, по петгодишни групи на возраст, по статистички региони, по години, според Попис 2002
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           25.6.2021
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudRevizija__RabotoSposobnoNaselenie/074_RabSpos_NadvorObrSis_Pol_ml.px/">
#            Работоспособно население кое учествува во образовни активности надвор од редовниот образовен систем според времето на посетување на образовните активности според пол, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           20.5.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/067_RabotsNasel_UcestvoObr_Pol_ml_arh.px/">
#            Работоспособно население според учеството во формалното (редовно) образование и во образовни активности надвор од редовниот образовен систем, по години, aрхивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__PazarNaTrud__PazarTrudArhiva__RabotoSposobnoNaselenieArhiva/074_RabSpos_NadvorObrSis_Pol_ml_arh.px/">
#            Работоспособно население кое учествува во образовни активности надвор од редовниот образовен систем според времето на посетување на образовните активности според пол, по години, архивирани податоци
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           22.5.2024
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__Demografija/T1054P21.px/">
#            Вкупно резидентно население на Република Северна Македонија на возраст над 15 години според брачниот статус, пол, возраст, по општини, Попис, 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.9.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__Demografija/T1055P21.px/">
#            Вкупно резидентно население на возраст над 15 години според видот на брачната заедницата во која живее, по возраст и пол, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.9.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__Demografija/T1056P21.px/">
#            Вкупно женско население  на Република Северна Македонија на возраст над 15 години според бројот на живородени деца, по возраст, по општини, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           30.9.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__ObrazovniKarakteristiki/T1029P21.px/">
#            Вкупно резидентно население на возраст од 15+ години според полето на образование во највисокиот степен на образование, пол и возраст, по општини, Попис, 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           01.6.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__ObrazovniKarakteristiki/T1031P21.px/">
#            Вкупно резидентно население на возраст од 5+ години во формалното (редовно) образование, според степенот на образование, пол и возраст, по општини, Попис, 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           01.6.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__ObrazovniKarakteristiki/T1032P21.px/">
#            Вкупно резидентно население на возраст од 15+ години во формалното (редовно) образование според  поле на образование, пол и возраст, по општини, Попис, 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           01.6.2022
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__EkonomskiKarakteristiki/T1038P21.px/">
#            Активно население кое врши занимање  на возраст од 15 години и повеќе, по пол според општината во која работи, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           02.12.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Naselenie__Vitalna/125_VitStat_Mk_PrDviz_ml.px/">
#            Преглед за природното движење на населението, 1931-2024
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           10.7.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__Popisi__Popis2021__NaselenieVkupno__NaseleniePopis2021__EkonomskiKarakteristiki/T1039P21.px/">
#            Вкупно работоспособно население на  возраст од 15 години и повеќе според пол и видот на превозното средство кое најчесто го користи до работа или школо, по општини, Попис 2021
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           01.6.2022
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/275_OdrzRaz_Mk_SDG_07_Energy_ml.px/">
#            ЦОР 7. Достапна и чиста енергија
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__CeliNaOdrzlivRazvojCOR2030/125_OdrzRaz_Mk_SDG_01_Nopoverty_ml.px/">
#            ЦОР 1. Свет без сиромаштија
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           31.7.2025
#          </td>
#         </tr>
#         <tr class="tableAlternatingRow">
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__OdrzlivRazvoj__IndikatoriZaOdrzlivRazvoj/325_OdrzRaz_Mk_05Javzdrav_mk.px/">
#            Јавно здравство, по години, по индикатори
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           21.9.2018
#          </td>
#         </tr>
#         <tr>
#          <td class="searchCell searchCellTable">
#           <a href="/PXWeb/pxweb/mk/MakStat/MakStat__BDP__BDPInvesGodisni__GodisniBDPsporedESS95/225_NacSmA_Mk_05M167_mk.px/">
#            Макроекономски индикатори, по години
#           </a>
#          </td>
#          <td class="searchCell searchCellPublished">
#           28.10.2013
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <script>
#        jQuery(document).ready(function () {
#             jQuery('[id$=rbAll]').click(function () {
#                 jQuery('.search-option').prop('disabled', true);
#                 jQuery('[id$=chkTitle]').prop('disabled', true);
#                 jQuery('[id$=chkValues]').prop('disabled', true);
#                 jQuery('[id$=chkCodes]').prop('disabled', true);
#                 return true;
#             });
#             jQuery('[id$=rbSelect]').click(function () {
#                 jQuery('.search-option').prop('disabled', false);
#                 jQuery('[id$=chkTitle]').prop('disabled', false);
#                 jQuery('[id$=chkValues]').prop('disabled', false);
#                 jQuery('[id$=chkCodes]').prop('disabled', false);
#                 return true;
#             });
#         });
#       </script>
#      </main>
#      <footer id="pxfooter">
#       <div class="footerleft">
#        <span id="ctl00_lblFooterText">
#        </span>
#       </div>
#       <div class="footerright">
#       </div>
#       <div style="clear: both;">
#       </div>
#      </footer>
#     </div>
#    </form>
#   </div>
#   <script>
#    "use strict";
#         // Set a variable for our button element.
#         var scrollToTopButton = document.getElementById('ctl00_ToTheTopButton');
#         var lastScrollYPos = 0;
#
#         scrollToTopButton.className = "top-link pxweb-btn negative hidden";
#
#         // Let's set up a function that shows our scroll-to-top button if we scroll beyond the height of the initial window.
#         var scrollFunc = function scrollFunc(lastScrollYPos) {
#             // Get the current scroll value
#             var y = window.pageYOffset; // If the scroll value is greater than the window height, let's add a class to the scroll-to-top button to show it!
#
#             if (y > 300 && y < lastScrollYPos) {
#                 scrollToTopButton.className = "top-link pxweb-btn negative show";
#             } else {
#                 scrollToTopButton.className = "top-link pxweb-btn negative hidden";
#                 scrollToTopButton.blur();
#             }
#         };
#
#         window.addEventListener('scroll', function (e) {
#             scrollFunc(lastScrollYPos);
#             lastScrollYPos = window.scrollY;
#         });
#
#         scrollToTopButton.onclick = function (e) {
#             e.preventDefault();
#             document.documentElement.scrollTop = 0;
#         };
#   </script>
#  </body>
# </html>

# %% [markdown]
# Проблем: горенаведеното пребарување честопати дава премногу опции.
#
# Затоа, би помогнало ако ги ограничиме резултатите на оние кои го содржат зборот во насловот на табелата.
#
# Како го правиме ова?
# - прво праќаме GET request за да го добиеме првичниот HTML и да ги утврдиме скриените инпут полиња (пр. __VIEWSTATE, __EVENTVALIDATION) кои потоа ќе ни бидат потребни за вториот POST request
# - потоа праќаме POST request со потребните филтри за да се пребаруваат само насловите според keyword
# - ги зачувуваме насловот, линкот до табелата, и датумот кога податоците биле објавени.

# %%
def keyword_search(keyword):
    session = requests.Session()

    # Step 1: initial GET
    r = session.get(MAKSTAT_URL, params={"searchquery": keyword})
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")

    # Step 2: collect hidden inputs
    data = {}
    for inp in soup.select("input[type=hidden]"):
        if inp.get("name"):
            data[inp["name"]] = inp.get("value", "")

    # Step 3: add your desired options
    data["ctl00$ContentPlaceHolderMain$pxSearch$txtSearch"] = keyword
    data["ctl00$ContentPlaceHolderMain$pxSearch$cmdSearch"] = "Пребарај"
    data["ctl00$ContentPlaceHolderMain$searchOptions"] = "select"   # "Пребарај само"
    data["ctl00$ContentPlaceHolderMain$chkTitle"] = "on"            # "Наслов на табелата"

    # Step 4: POST back
    r2 = session.post(MAKSTAT_URL, data=data)
    r2.raise_for_status()

    # wrap in soup
    soup2 = BeautifulSoup(r2.text, "html.parser")

    rows = soup2.select("tr")
    results = {"titles": [], "links": [], "published": []}

    for row in rows:
        a = row.select_one("td.searchCellTable a")
        pub = row.select_one("td.searchCellPublished")
        if a and pub:
            results["titles"].append(a.get_text(strip=True))
            results["links"].append("https://makstat.stat.gov.mk" + a["href"])
            results["published"].append(pub.get_text(strip=True))

    return results

if __name__ == "__main__":
    data = keyword_search("трговија")
    df = pd.DataFrame.from_dict(data)
    print(df)
    for t, l, p in zip(data["titles"], data["links"], data["published"]):
        print(f"{p} – {t} → {l}")
# Out:
#                                               titles  \
# 0  Е-трговија кај деловните субјекти од нефинанси...
# 1  Промет во трговијата со моторни возила, тргови...
#
#                                                links  published
# 0  https://makstat.stat.gov.mk/PXWeb/pxweb/mk/Mak...  08.4.2025
# 1  https://makstat.stat.gov.mk/PXWeb/pxweb/mk/Mak...  01.9.2025
# 08.4.2025 – Е-трговија кај деловните субјекти од нефинансискиот сектор, со 10 или повеќе вработени (%) → https://makstat.stat.gov.mk/PXWeb/pxweb/mk/MakStat/MakStat__InfOpstestvo__DelovniSubjekti/325_InfOpst_Mk_12Entecom_ml.px/
# 01.9.2025 – Промет во трговијата со моторни возила, трговија на големо и на мало, по НКД Рев. 2, по месеци → https://makstat.stat.gov.mk/PXWeb/pxweb/mk/MakStat/MakStat__VnatresnaTrgovija__VTBazna2021/125_Vt_mk_11_TrgDej_2021_ml.px/

# %%
df = pd.DataFrame.from_dict(data)
df
# Out:
#                                               titles  \
# 0  Е-трговија кај деловните субјекти од нефинанси...
# 1  Промет во трговијата со моторни возила, тргови...
#
#                                                links  published
# 0  https://makstat.stat.gov.mk/PXWeb/pxweb/mk/Mak...  08.4.2025
# 1  https://makstat.stat.gov.mk/PXWeb/pxweb/mk/Mak...  01.9.2025

# %%
data['links'][0]
# Out:
# 'https://makstat.stat.gov.mk/PXWeb/pxweb/mk/MakStat/MakStat__InfOpstestvo__DelovniSubjekti/325_InfOpst_Mk_12Entecom_ml.px/'

# %% [markdown]
# Линк од резултатите на пребарувањето:
# ```
# https://makstat.stat.gov.mk/PXWeb/pxweb/mk/MakStat/MakStat__InfOpstestvo__DelovniSubjekti/325_InfOpst_Mk_12Entecom_ml.px/
# ```
#
# Линк од API endpoint:
# ```
# https://makstat.stat.gov.mk:443/PXWeb/api/v1/mk/MakStat/InfOpstestvo/DelovniSubjekti/325_InfOpst_Mk_12Entecom_ml.px
# ```

# %%
API_BASE_URL = "https://makstat.stat.gov.mk:443/PXWeb/api/v1/"

test_url = data['links'][0]
API_suffix = test_url.replace("MakStat__", "").replace("__", "/").split("pxweb/")[1]
print(API_suffix)
# Out:
# mk/MakStat/InfOpstestvo/DelovniSubjekti/325_InfOpst_Mk_12Entecom_ml.px/

# %%
import requests
import json

TABLE_URL = API_BASE_URL + API_suffix

print(TABLE_URL)

query = {
  "query": [],
  "response": {
    "format": "px"
  }
}

TEST_URL = "https://makstat.stat.gov.mk:443/PXWeb/api/v1/mk/MakStat/InfOpstestvo/DelovniSubjekti/325_InfOpst_Mk_12Entecom_ml.px"

response = requests.post(TABLE_URL, json=query)

# Check if the request was successful
if response.status_code == 200:
    print("Request successful!")
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# https://makstat.stat.gov.mk:443/PXWeb/api/v1/mk/MakStat/InfOpstestvo/DelovniSubjekti/325_InfOpst_Mk_12Entecom_ml.px/
# Request successful!

# %%
# !pip install pyaxis
# Out:
# Requirement already satisfied: pyaxis in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyaxis) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pyaxis) (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pyaxis) (2.2.2)
# Requirement already satisfied: pyjstat in /usr/local/lib/python3.12/dist-packages (from pyaxis) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pyaxis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pyaxis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pyaxis) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pyaxis) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pyaxis) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pyaxis) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pyaxis) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pyaxis) (1.17.0)

# %%
from pyaxis import pyaxis

with open("result.px", 'wb') as f:
    f.write(response.content)

result = pyaxis.parse('result.px', encoding='utf-8')#, 'ISO-8859-5')

table_df = pd.DataFrame(result['DATA'])

table_df.to_markdown()
# Out:
# Multilingual PX file
# '|    | Деловни субјекти (10+) кои имале е-трговија                                                               |   Година | DATA   |\n|---:|:----------------------------------------------------------------------------------------------------------|---------:|:-------|\n|  0 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2006 | 14.6   |\n|  1 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2007 | 7.9    |\n|  2 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2008 | 9.8    |\n|  3 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2009 | 7.1    |\n|  4 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2010 | 6.8    |\n|  5 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2011 | 8.1    |\n|  6 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2012 | 5.1    |\n|  7 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2013 | 4.6    |\n|  8 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2014 | 5.0    |\n|  9 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2015 | 5.9    |\n| 10 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2016 | 5.6    |\n| 11 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2017 | 5.8    |\n| 12 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2018 | "..."  |\n| 13 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2019 | "..."  |\n| 14 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2020 | "..."  |\n| 15 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2021 | "..."  |\n| 16 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2022 | "..."  |\n| 17 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2023 | "..."  |\n| 18 | Деловни субјекти кои нарачале преку интернет или други компјутерски посредувани мрежи (е-купување)        |     2024 | "..."  |\n| 19 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2006 | 6.2    |\n| 20 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2007 | 3.7    |\n| 21 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2008 | 5.8    |\n| 22 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2009 | 4.3    |\n| 23 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2010 | 4.2    |\n| 24 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2011 | 7.0    |\n| 25 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2012 | 5.8    |\n| 26 | Деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) |     2013 | 6.1    |\n| 27 | Деловни субјекти кои примиле нарачки преку интер ...

# %%
table_df
# Out:
#           Деловни субјекти (10+) кои имале е-трговија Година   DATA
# 0   Деловни субјекти кои нарачале преку интернет и...   2006   14.6
# 1   Деловни субјекти кои нарачале преку интернет и...   2007    7.9
# 2   Деловни субјекти кои нарачале преку интернет и...   2008    9.8
# 3   Деловни субјекти кои нарачале преку интернет и...   2009    7.1
# 4   Деловни субјекти кои нарачале преку интернет и...   2010    6.8
# 5   Деловни субјекти кои нарачале преку интернет и...   2011    8.1
# 6   Деловни субјекти кои нарачале преку интернет и...   2012    5.1
# 7   Деловни субјекти кои нарачале преку интернет и...   2013    4.6
# 8   Деловни субјекти кои нарачале преку интернет и...   2014    5.0
# 9   Деловни субјекти кои нарачале преку интернет и...   2015    5.9
# 10  Деловни субјекти кои нарачале преку интернет и...   2016    5.6
# 11  Деловни субјекти кои нарачале преку интернет и...   2017    5.8
# 12  Деловни субјекти кои нарачале преку интернет и...   2018  "..."
# 13  Деловни субјекти кои нарачале преку интернет и...   2019  "..."
# 14  Деловни субјекти кои нарачале преку интернет и...   2020  "..."
# 15  Деловни субјекти кои нарачале преку интернет и...   2021  "..."
# 16  Деловни субјекти кои нарачале преку интернет и...   2022  "..."
# 17  Деловни субјекти кои нарачале преку интернет и...   2023  "..."
# 18  Деловни субјекти кои нарачале преку интернет и...   2024  "..."
# 19  Деловни субјекти кои примиле нарачки преку инт...   2006    6.2
# 20  Деловни субјекти кои примиле нарачки преку инт...   2007    3.7
# 21  Деловни субјекти кои примиле нарачки преку инт...   2008    5.8
# 22  Деловни субјекти кои примиле нарачки преку инт...   2009    4.3
# 23  Деловни субјекти кои примиле нарачки преку инт...   2010    4.2
# 24  Деловни субјекти кои примиле нарачки преку инт...   2011    7.0
# 25  Деловни субјекти кои примиле нарачки преку инт...   2012    5.8
# 26  Деловни субјекти кои примиле нарачки преку инт...   2013    6.1
# 27  Деловни субјекти кои примиле нарачки преку инт...   2014    7.0
# 28  Деловни субјекти кои примиле нарачки преку инт...   2015    3.6
# 29  Деловни субјекти кои примиле нарачки преку инт...   2016    7.4
# 30  Деловни субјекти кои примиле нарачки преку инт...   2017    6.0
# 31  Деловни субјекти кои примиле нарачки преку инт...   2018    5.7
# 32  Деловни субјекти кои примиле нарачки преку инт...   2019    3.6
# 33  Деловни субјекти кои примиле нарачки преку инт...   2020    6.2
# 34  Деловни субјекти кои примиле нарачки преку инт...   2021    9.6
# 35  Деловни субјекти кои примиле нарачки преку инт...   2022   13.5
# 36  Деловни субјекти кои примиле нарачки преку инт...   2023   14.7
# 37  Деловни субјекти кои примиле нарачки преку инт...   2024   19.7

# %% [markdown]
# # Дел 2: евалуација
#
# Евалуација звучи како дел кој се одвива после имплементацијата, но клучно е да се направи што е можно порано, поради две главни причини:
# - утврдува мерлива цел, открива скриени потешкотии,
# - **овозможува оптимизација на перформанс *за време на имплементацијата***.

# %%
system_prompt = """

Твојата задача е да генерираш прашања и клуч на точни одговори врз основа на табела која ќе ти биде дадена.

За секоја табела, треба да одговориш во JSON format со следниве полиња:

- question: прашањето, на македонски јазик, во врска со некој податок од табелата
- answer: точниот одговор на прашањето

За секоја табела, генерирај еден пар од прашање и одговор.
"""


import requests
import json
import os
from google.colab import userdata

url = "https://openrouter.ai/api/v1/chat/completions"
headers = {
  "Authorization": f"Bearer {userdata.get('OPENROUTER_API_KEY')}",
  "Content-Type": "application/json"
}



def generate_synthetic_data(tables, N=10):
    """
    Params:
    - tables: list of table (in pandas DataFrame format) to generate synthetic data for
    - N: number of synthetic data points to generate for each table
    """

    QA_pairs = []
    for table in tables:
        payload = {
        "model": "google/gemini-2.5-flash",
        "messages": [
            {
            "role": "system",
            "content": system_prompt
            },
            {
            "role": "user",
            "content": table.to_markdown()
            }
        ]
        }

        response = requests.post(url, headers=headers, json=payload)
        pair = response.json()['choices'][0]['message']['content']
        QA_pairs.append(pair)

    return QA_pairs


eval_set = generate_synthetic_data([table_df])

eval_set
# Out:
# ['```json\n{\n  "question": "Колку деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) имало во 2017 година?",\n  "answer": "6.0"\n}\n```']

# %%
import json

for i in eval_set:
    # Step 1: Strip the outer list and ```json markers
    cleaned = i.strip("['```json\n").rstrip("\n```']")

    # Step 2: Parse the JSON
    data = json.loads(cleaned)

    #eval_df = pd.DataFrame.from_dict(data)

data
# Out:
# {'question': 'Колку деловни субјекти кои примиле нарачки преку интернет или други компјутерски посредувани мрежи (е-продажба) имало во 2017 година?',
#  'answer': '6.0'}

# %% [markdown]
# Следни чекори:
#
# 1. Интегрирање на алатките и креирање функционален агент. Цел: прототип каде што корисник пишува прашање -> агентот пребарува МАКСТАТ со клучен збор -> добива листа на табели -> избира табела -> табелата е преземена и претворена во DataFrame
#
# 2. Креирање на синтетички сет за евалуација (100 прашања), кој се состои од `question`, `search_keyword`, `table_name`, `sql_query`, `answer`.
#
# Дизајн одлуки околу евалуациското множество:
#
# - Системската порака за моделот кој ги генерира синтетичките податоци треба да разјасни дека `seach_keyword` мора да биде содржан во `table_name`. Ова овозможува да го увидиме перформансот на моделот кој пребарува ако функцијата за пребарување секогаш ги филтрира резултатите со "само наслов".
#
# - за некои прашања, `answer` е integer или float ("колку деловни субјекти кои направиле X имало во 2017 година"). За други прашања, `answer` е под-табела (ако корисникот праша "дај ми ги податоците за X од Гостивар"). Во вториов случај, треба да се евалуира и/или оптимизира моделот врз основа на конкретното SQL query, а целиот процес врз основа на резултатот.
#
# - Множеството треба да овозможи изолирано тестирање на различните делови од процесот. На пример, може една евалуација да биде кој модел е најдобар во извлекување на правилната `table_name` според даденото `question`; друга евалуација да биде колку добар е моделот во давање на `answer` врз основа на одредена `table_name`; а ултимативната евалуација, секако, е перформансот во давање на `answer` базиран на `question`.
#
#
# Следен состанок: оптимизација со [DSPy](https://dspy.ai/api/optimizers/MIPROv2/).
